# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import pymongo
from pymongo import MongoClient,ASCENDING, DESCENDING
import pymongo,json
from pymongo import InsertOne, DeleteOne, ReplaceOne
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
client = pymongo.MongoClient(host='localhost', port=27017)

# %%
db_News=client.News
db_twitter=client.TwitterTP

# %% [markdown]
# # TWITTER
# FIND SPECIFIC TIME PERIOD OF DATA

# %%
aa=['9:00-10:00','12:00-13:00','15:00-16:00','18:00-19:00','21:00-22:00']

# %%
a=np.zeros(shape=(5,7))

# %%
a[0,0]=db_twitter.Twitter1210_ALL.find({'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}}).count()
a[1,0]=db_twitter.Twitter1210_ALL.find({'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}}).count()
a[2,0]=db_twitter.Twitter1210_ALL.find({'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}}).count()
a[3,0]=db_twitter.Twitter1210_ALL.find({'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}}).count()
a[4,0]=db_twitter.Twitter1210_ALL.find({'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}}).count()
a[0,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}).count()
a[1,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}).count()
a[2,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}).count()
a[3,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}).count()
a[4,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}).count()
a[0,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}).count()
a[1,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}).count()
a[2,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}).count()
a[3,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}).count()
a[4,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}).count()
a[0,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}).count()
a[1,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}).count()
a[2,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}).count()
a[3,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}).count()
a[4,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}).count()
a[0,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}).count()
a[1,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}).count()
a[2,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}).count()
a[3,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}).count()
a[4,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}).count()
a[3,4]=a[3,4]*4
a[0,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}).count()
a[1,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}).count()
a[2,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}).count()
a[3,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}).count()
a[4,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}).count()
a[0,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}).count()
a[1,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}).count()
a[2,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}).count()
a[3,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}).count()
a[4,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}).count()
a
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# ...

# %% [markdown]
# #### Twitter1210_ALL

# %%
a[0,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}).count()
a[1,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}).count()
a[2,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}).count()
a[3,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}).count()
a[4,1]=db_twitter.Twitter1204_ALL.find({'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}).count()
a[:,1]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# array([27190., 34999., 48515., 63635., 62183.])

# %% [markdown]
# #### Twitter1204_ALL

# %%
a[0,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}).count()
a[1,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}).count()
a[2,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}).count()
a[3,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}).count()
a[4,2]=db_twitter.Twitter1205_ALL.find({'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}).count()
a[:,2]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# array([36027., 50172., 61840., 63515., 72142.])

# %% [markdown]
# #### Twitter1205_ALL

# %%
a[0,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}).count()
a[1,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}).count()
a[2,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}).count()
a[3,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}).count()
a[4,3]=db_twitter.Twitter1206_ALL.find({'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}).count()
a[:,3]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# array([36113., 47003., 60413., 57311., 61007.])

# %% [markdown]
# #### Twitter1206_ALL

# %%
a[0,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}).count()
a[1,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}).count()
a[2,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}).count()
a[3,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}).count()
a[4,4]=db_twitter.Twitter1207_ALL.find({'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}).count()
a[:,4]
a[3,4]=a[3,4]*4
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """

# %% [markdown]
# #### Twitter1207_ALL

# %%
a[0,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}).count()
a[1,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}).count()
a[2,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}).count()
a[3,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}).count()
a[4,5]=db_twitter.Twitter1208_ALL.find({'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}).count()
a[:,5]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# array([36439., 45775., 62158., 61674., 54568.])

# %% [markdown]
# #### Twitter1208_ALL

# %%
a[0,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}).count()
a[1,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}).count()
a[2,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}).count()
a[3,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}).count()
a[4,6]=db_twitter.Twitter1209_ALL.find({'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}).count()
a[:,6]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# array([35998., 42804., 61279., 60120., 66003.])

# %% [markdown]
# #### Twitter1209_ALL

# %%
col_count = 5
bar_width = 0.05
index = np.arange(col_count)

# %%
bb=["MON","TUE","WED","THU","FRI","SAT","SUN"]

# %%
fig=plt.figure(figsize=(25,8))
A = plt.bar(index,
           a[:,0], 
           bar_width,
           alpha=.4,
           label="MON") 
B = plt.bar(index+0.12,
            a[:,1],
            bar_width,
            alpha=.4,
            label="TUE") 
C = plt.bar(index+0.24,
            a[:,2],
            bar_width,
            alpha=.4,
            label="WED") # x,y ,width
D = plt.bar(index+0.36,
            a[:,3],
            bar_width,
            alpha=.4,
            label="THU") # x,y ,width
E = plt.bar(index+0.48,
           a[:,4], 
           bar_width,
           alpha=.4,
           label="FRI") 
F = plt.bar(index+0.6,
            a[:,5],
            bar_width,
            alpha=.4,
            label="SAT") 
G = plt.bar(index+0.72,
            a[:,6],
            bar_width,
            alpha=.4,
            label="SUN") # x,y ,width


def createLabels(data):
    for item in data:
        height = item.get_height()
        plt.text(
            (item.get_x()+item.get_width()), 
            height+1000, 
            '%d' % int(height),
            ha = "right",
            va = "bottom",
            withdash=False
        )

createLabels(A)
createLabels(B)
createLabels(C)
createLabels(D)
createLabels(E)
createLabels(F)
createLabels(G)

plt.ylabel("Numbers Of Tweets",size=14)
plt.xlabel("Time Period (1 hour)",size=14)
plt.title("Numbers Of Tweets by hours in weeks",size=20)
plt.xticks(index+.7 / 2 ,(aa),size=14)
plt.legend() 
plt.grid(True)
plt.show()

# %%
fig = plt.figure(figsize=[10,7.5],facecolor=(239/255,248/255,253/255))
ax1=fig.add_subplot(1,1,1,facecolor=(239/255,248/255,253/255))
width=0.3
alpha=0.8
ax1.spines['top'].set_visible(False)
# ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)

ax1.stackplot(bb,a[0,:]+a[1,:]+a[2,:]+a[3,:]+a[4,:],color=(253/255,222/255,194/255),alpha=1)
ax1.stackplot(bb,a[0,:]+a[1,:]+a[2,:]+a[3,:],color=(188/255,205/255,225/255),alpha=1)
ax1.stackplot(bb,a[0,:]+a[1,:]+a[2,:],color=(239/255,194/255,188/255),alpha=1)
ax1.stackplot(bb,a[0,:]+a[1,:],color=(237/255,231/255,195/255),alpha=1)
ax1.stackplot(bb,a[0,:],color=(215/255,215/255,215/255),alpha=1)

ax1.bar(bb,a[0,:]+a[1,:]+a[2,:]+a[3,:]+a[4,:],width,color=(243/255,133/255,36/255))
ax1.bar(bb,a[0,:]+a[1,:]+a[2,:]+a[3,:],width,color=(65/255,113/255,156/255))
ax1.bar(bb,a[0,:]+a[1,:]+a[2,:],width,color=(200/255,35/255,52/255))
ax1.bar(bb,a[0,:]+a[1,:],width,color=(195/255,169/255,48/255))
ax1.bar(bb,a[0,:],width,color=(100/255,100/255,100/255))

ax1.text(6.25,20000,aa[0],ha='left',va='center',fontsize=14.5,color=(100/255,100/255,100/255))
ax1.text(6.25,60000,aa[1],ha='left',va='center',fontsize=14.5,color=(195/255,169/255,48/255))
ax1.text(6.25,110000,aa[2],ha='left',va='center',fontsize=14.5,color=(200/255,35/255,52/255))
ax1.text(6.25,175000,aa[3],ha='left',va='center',fontsize=14.5,color=(65/255,113/255,156/255))
ax1.text(6.25,225000,aa[4],ha='left',va='center',fontsize=14.5,color=(243/255,133/255,36/255))
# Out:
# Text(6.25,225000,'21:00-22:00')

# %%
d1=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}})
d2=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}})
d3=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}})
d4=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}})
d5=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}})

for d11,d22,d33,d44,d55 in zip(d1,d2,d3,d4,d5):
    db_twitter.Twitter1210_REMOVENOISE1.insert_one(d11)
    db_twitter.Twitter1210_REMOVENOISE2.insert_one(d22)
    db_twitter.Twitter1210_REMOVENOISE3.insert_one(d33)
    db_twitter.Twitter1210_REMOVENOISE4.insert_one(d44)
    db_twitter.Twitter1210_REMOVENOISE5.insert_one(d55)

# %%
b=np.zeros(shape=(5,7))

# %%
b[0,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}}]}).count()
b[1,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}}]}).count()
b[2,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}}]}).count()
b[3,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}}]}).count()
b[4,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}}]}).count()
b[0,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}]}).count()
b[1,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}]}).count()
b[2,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}]}).count()
b[3,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}]}).count()
b[4,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}]}).count()
b[0,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}]}).count()
b[1,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}]}).count()
b[2,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}]}).count()
b[3,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}]}).count()
b[4,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}]}).count()
b[0,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}]}).count()
b[1,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}]}).count()
b[2,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}]}).count()
b[3,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}]}).count()
b[4,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}]}).count()
b[0,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}]}).count()
b[1,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}]}).count()
b[2,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}]}).count()
b[3,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}]}).count()
b[4,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}]}).count()
b[3,4]=b[3,4]*4
b[0,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}]}).count()
b[1,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}]}).count()
b[2,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}]}).count()
b[3,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}]}).count()
b[4,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}]}).count()
b[0,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}]}).count()
b[1,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}]}).count()
b[2,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}]}).count()
b[3,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}]}).count()
b[4,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {"place":None},{'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}]}).count()
b
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# ...

# %% [markdown]
# #### Percetages Of Tweets With Geo-tagged

# %%
c[0,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}}]}).count()
c[1,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}}]}).count()
c[2,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}}]}).count()
c[3,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}}]}).count()
c[4,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}}]}).count()
c[0,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}]}).count()
c[1,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}]}).count()
c[2,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}]}).count()
c[3,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}]}).count()
c[4,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}]}).count()
c[0,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}]}).count()
c[1,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}]}).count()
c[2,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}]}).count()
c[3,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}]}).count()
c[4,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}]}).count()
c[0,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}]}).count()
c[1,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}]}).count()
c[2,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}]}).count()
c[3,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}]}).count()
c[4,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}]}).count()
c[0,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}]}).count()
c[1,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}]}).count()
c[2,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}]}).count()
c[3,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}]}).count()
c[4,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}]}).count()
c[3,4]=c[3,4]*4
c[0,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}]}).count()
c[1,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}]}).count()
c[2,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}]}).count()
c[3,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}]}).count()
c[4,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}]}).count()
c[0,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}]}).count()
c[1,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}]}).count()
c[2,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}]}).count()
c[3,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}]}).count()
c[4,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'retweeted_status':{'$ne': None}},{'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}]}).count()
c
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# ...

# %%
d=np.zeros(shape=(5,7))
d[0,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}}]}).count()
d[1,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}}]}).count()
d[2,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}}]}).count()
d[3,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}}]}).count()
d[4,0]=db_twitter.Twitter1210_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}}]}).count()
d[0,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}]}).count()
d[1,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}]}).count()
d[2,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}]}).count()
d[3,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}]}).count()
d[4,1]=db_twitter.Twitter1204_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}]}).count()
d[0,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}]}).count()
d[1,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}]}).count()
d[2,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}]}).count()
d[3,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}]}).count()
d[4,2]=db_twitter.Twitter1205_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}]}).count()
d[0,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}]}).count()
d[1,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}]}).count()
d[2,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}]}).count()
d[3,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}]}).count()
d[4,3]=db_twitter.Twitter1206_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}]}).count()
d[0,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}]}).count()
d[1,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}]}).count()
d[2,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}]}).count()
d[3,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}]}).count()
d[4,4]=db_twitter.Twitter1207_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}]}).count()
d[3,4]=d[3,4]*4
d[0,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}]}).count()
d[1,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}]}).count()
d[2,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}]}).count()
d[3,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}]}).count()
d[4,5]=db_twitter.Twitter1208_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}]}).count()
d[0,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}]}).count()
d[1,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}]}).count()
d[2,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}]}).count()
d[3,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}]}).count()
d[4,6]=db_twitter.Twitter1209_ALL.find({"$and": [ {'is_quote_status':True},{'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}]}).count()
d
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# ...

# %%
fig = plt.figure(figsize=[10,20],facecolor=(239/255,248/255,253/255))
ax1=fig.add_subplot(3,1,1,facecolor=(239/255,248/255,253/255))
width=0.3
ax1.spines['top'].set_visible(False)
# ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)

ax1.stackplot(bb,b[0,:]+b[1,:]+b[2,:]+b[3,:]+b[4,:],color=(253/255,222/255,194/255),alpha=1)
ax1.stackplot(bb,b[0,:]+b[1,:]+b[2,:]+b[3,:],color=(188/255,205/255,225/255),alpha=1)
ax1.stackplot(bb,b[0,:]+b[1,:]+b[2,:],color=(239/255,194/255,188/255),alpha=1)
ax1.stackplot(bb,b[0,:]+b[1,:],color=(237/255,231/255,195/255),alpha=1)
ax1.stackplot(bb,b[0,:],color=(215/255,215/255,215/255),alpha=1)

ax1.bar(bb,b[0,:]+b[1,:]+b[2,:]+b[3,:]+b[4,:],width,color=(243/255,133/255,36/255))
ax1.bar(bb,b[0,:]+b[1,:]+b[2,:]+b[3,:],width,color=(65/255,113/255,156/255))
ax1.bar(bb,b[0,:]+b[1,:]+b[2,:],width,color=(200/255,35/255,52/255))
ax1.bar(bb,b[0,:]+b[1,:],width,color=(195/255,169/255,48/255))
ax1.bar(bb,b[0,:],width,color=(100/255,100/255,100/255))

ax1.text(6.25,np.mean(b[0,:]),aa[0],ha='left',va='center',fontsize=14.5,color=(100/255,100/255,100/255))
ax1.text(6.25,np.mean(b[0,:]+b[1,:]),aa[1],ha='left',va='center',fontsize=14.5,color=(195/255,169/255,48/255))
ax1.text(6.25,np.mean(b[0,:]+b[1,:]+b[2,:]),aa[2],ha='left',va='center',fontsize=14.5,color=(200/255,35/255,52/255))
ax1.text(6.25,np.mean(b[0,:]+b[1,:]+b[2,:]+b[3,:]),aa[3],ha='left',va='center',fontsize=14.5,color=(65/255,113/255,156/255))
ax1.text(6.25,np.mean(b[0,:]+b[1,:]+b[2,:]+b[3,:]+b[4,:]),aa[4],ha='left',va='center',fontsize=14.5,color=(243/255,133/255,36/255))

plt.ylabel("Numbers Of Tweets With Geo-tagged",size=12)
plt.xlabel("Time Period",size=12)
plt.title("Numbers Of Tweets With Geo-tagged by hours in weeks",size=16)

ax1=fig.add_subplot(3,1,2,facecolor=(239/255,248/255,253/255))
width=0.3
ax1.spines['top'].set_visible(False)
# ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)

ax1.stackplot(bb,c[0,:]+c[1,:]+c[2,:]+c[3,:]+c[4,:],color=(253/255,222/255,194/255),alpha=1)
ax1.stackplot(bb,c[0,:]+c[1,:]+c[2,:]+c[3,:],color=(188/255,205/255,225/255),alpha=1)
ax1.stackplot(bb,c[0,:]+c[1,:]+c[2,:],color=(239/255,194/255,188/255),alpha=1)
ax1.stackplot(bb,c[0,:]+c[1,:],color=(237/255,231/255,195/255),alpha=1)
ax1.stackplot(bb,c[0,:],color=(215/255,215/255,215/255),alpha=1)

ax1.bar(bb,c[0,:]+c[1,:]+c[2,:]+c[3,:]+c[4,:],width,color=(243/255,133/255,36/255))
ax1.bar(bb,c[0,:]+c[1,:]+c[2,:]+c[3,:],width,color=(65/255,113/255,156/255))
ax1.bar(bb,c[0,:]+c[1,:]+c[2,:],width,color=(200/255,35/255,52/255))
ax1.bar(bb,c[0,:]+c[1,:],width,color=(195/255,169/255,48/255))
ax1.bar(bb,c[0,:],width,color=(100/255,100/255,100/255))

ax1.text(6.25,np.mean(c[0,:]),aa[0],ha='left',va='center',fontsize=14.5,color=(100/255,100/255,100/255))
ax1.text(6.25,np.mean(c[0,:]+c[1,:]),aa[1],ha='left',va='center',fontsize=14.5,color=(195/255,169/255,48/255))
ax1.text(6.25,np.mean(c[0,:]+c[1,:]+c[2,:]),aa[2],ha='left',va='center',fontsize=14.5,color=(200/255,35/255,52/255))
ax1.text(6.25,np.mean(c[0,:]+c[1,:]+c[2,:]+c[3,:]),aa[3],ha='left',va='center',fontsize=14.5,color=(65/255,113/255,156/255))
ax1.text(6.25,np.mean(c[0,:]+c[1,:]+c[2,:]+c[3,:]+c[4,:]),aa[4],ha='left',va='center',fontsize=14.5,color=(243/255,133/255,36/255))

plt.ylabel("Numbers Of Retweets",size=12)
plt.xlabel("Time Period",size=12)
plt.title("Numbers Of Retweets by hours in weeks",size=16)

ax1=fig.add_subplot(3,1,3,facecolor=(239/255,248/255,253/255))
width=0.3
ax1.spines['top'].set_visible(False)
# ax1.spines['bottom'].set_visible(False)
ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)

ax1.stackplot(bb,d[0,:]+d[1,:]+d[2,:]+d[3,:]+d[4,:],color=(253/255,222/255,194/255),alpha=1)
ax1.stackplot(bb,d[0,:]+d[1,:]+d[2,:]+d[3,:],color=(188/255,205/255,225/255),alpha=1)
ax1.stackplot(bb,d[0,:]+d[1,:]+d[2,:],color=(239/255,194/255,188/255),alpha=1)
ax1.stackplot(bb,d[0,:]+d[1,:],color=(237/255,231/255,195/255),alpha=1)
ax1.stackplot(bb,d[0,:],color=(215/255,215/255,215/255),alpha=1)

ax1.bar(bb,d[0,:]+d[1,:]+d[2,:]+d[3,:]+d[4,:],width,color=(243/255,133/255,36/255))
ax1.bar(bb,d[0,:]+d[1,:]+d[2,:]+d[3,:],width,color=(65/255,113/255,156/255))
ax1.bar(bb,d[0,:]+d[1,:]+d[2,:],width,color=(200/255,35/255,52/255))
ax1.bar(bb,d[0,:]+d[1,:],width,color=(195/255,169/255,48/255))
ax1.bar(bb,d[0,:],width,color=(100/255,100/255,100/255))

ax1.text(6.25,np.mean(d[0,:]),aa[0],ha='left',va='center',fontsize=14.5,color=(100/255,100/255,100/255))
ax1.text(6.25,np.mean(d[0,:]+d[1,:]),aa[1],ha='left',va='center',fontsize=14.5,color=(195/255,169/255,48/255))
ax1.text(6.25,np.mean(d[0,:]+d[1,:]+d[2,:]),aa[2],ha='left',va='center',fontsize=14.5,color=(200/255,35/255,52/255))
ax1.text(6.25,np.mean(d[0,:]+d[1,:]+d[2,:]+d[3,:]),aa[3],ha='left',va='center',fontsize=14.5,color=(65/255,113/255,156/255))
ax1.text(6.25,np.mean(d[0,:]+d[1,:]+d[2,:]+d[3,:]+d[4,:]),aa[4],ha='left',va='center',fontsize=14.5,color=(243/255,133/255,36/255))

plt.ylabel("Numbers Of Quotes",size=12)
plt.xlabel("Time Period",size=12)
plt.title("Numbers Of Quotes by hours in weeks",size=16)
# Out:
# Text(0.5,1,'Numbers Of Quotes by hours in weeks')

# %%
e=np.zeros(shape=(5,7))
e[0,0]=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 09:05:00 +0000 2018","$lte":"Mon Dec 10 10:05:00 +0000 2018"}}).count()
e[1,0]=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 12:05:00 +0000 2018","$lte":"Mon Dec 10 13:05:00 +0000 2018"}}).count()
e[2,0]=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 15:03:00 +0000 2018","$lte":"Mon Dec 10 16:03:00 +0000 2018"}}).count()
e[3,0]=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 18:26:00 +0000 2018","$lte":"Mon Dec 10 19:26:00 +0000 2018"}}).count()
e[4,0]=db_twitter.Twitter1210_REMOVENOISE.find({'created_at': {"$gte":"Mon Dec 10 21:49:00 +0000 2018","$lte":"Mon Dec 10 22:49:00 +0000 2018"}}).count()
e[0,1]=db_twitter.Twitter1204_REMOVENOISE.find({'created_at': {"$gte":"Tue Dec 04 09:00:00 +0000 2018","$lte":"Tue Dec 04 10:00:00 +0000 2018"}}).count()
e[1,1]=db_twitter.Twitter1204_REMOVENOISE.find({'created_at': {"$gte":"Tue Dec 04 12:00:00 +0000 2018","$lte":"Tue Dec 04 13:00:00 +0000 2018"}}).count()
e[2,1]=db_twitter.Twitter1204_REMOVENOISE.find({'created_at': {"$gte":"Tue Dec 04 15:02:00 +0000 2018","$lte":"Tue Dec 04 16:02:00 +0000 2018"}}).count()
e[3,1]=db_twitter.Twitter1204_REMOVENOISE.find({'created_at': {"$gte":"Tue Dec 04 18:00:00 +0000 2018","$lte":"Tue Dec 04 19:00:00 +0000 2018"}}).count()
e[4,1]=db_twitter.Twitter1204_REMOVENOISE.find({'created_at': {"$gte":"Tue Dec 04 21:00:00 +0000 2018","$lte":"Tue Dec 04 22:00:00 +0000 2018"}}).count()
e[0,2]=db_twitter.Twitter1205_REMOVENOISE.find({'created_at': {"$gte":"Wed Dec 05 09:00:00 +0000 2018","$lte":"Wed Dec 05 10:00:00 +0000 2018"}}).count()
e[1,2]=db_twitter.Twitter1205_REMOVENOISE.find({'created_at': {"$gte":"Wed Dec 05 12:00:00 +0000 2018","$lte":"Wed Dec 05 13:00:00 +0000 2018"}}).count()
e[2,2]=db_twitter.Twitter1205_REMOVENOISE.find({'created_at': {"$gte":"Wed Dec 05 15:06:00 +0000 2018","$lte":"Wed Dec 05 16:06:00 +0000 2018"}}).count()
e[3,2]=db_twitter.Twitter1205_REMOVENOISE.find({'created_at': {"$gte":"Wed Dec 05 18:00:00 +0000 2018","$lte":"Wed Dec 05 19:00:00 +0000 2018"}}).count()
e[4,2]=db_twitter.Twitter1205_REMOVENOISE.find({'created_at': {"$gte":"Wed Dec 05 21:07:00 +0000 2018","$lte":"Wed Dec 05 22:07:00 +0000 2018"}}).count()
e[0,3]=db_twitter.Twitter1206_REMOVENOISE.find({'created_at': {"$gte":"Thu Dec 06 09:00:00 +0000 2018","$lte":"Thu Dec 06 10:00:00 +0000 2018"}}).count()
e[1,3]=db_twitter.Twitter1206_REMOVENOISE.find({'created_at': {"$gte":"Thu Dec 06 12:12:00 +0000 2018","$lte":"Thu Dec 06 13:12:00 +0000 2018"}}).count()
e[2,3]=db_twitter.Twitter1206_REMOVENOISE.find({'created_at': {"$gte":"Thu Dec 06 15:13:00 +0000 2018","$lte":"Thu Dec 06 16:13:00 +0000 2018"}}).count()
e[3,3]=db_twitter.Twitter1206_REMOVENOISE.find({'created_at': {"$gte":"Thu Dec 06 18:21:00 +0000 2018","$lte":"Thu Dec 06 19:21:00 +0000 2018"}}).count()
e[4,3]=db_twitter.Twitter1206_REMOVENOISE.find({'created_at': {"$gte":"Thu Dec 06 21:00:00 +0000 2018","$lte":"Thu Dec 06 22:00:00 +0000 2018"}}).count()
e[0,4]=db_twitter.Twitter1207_REMOVENOISE.find({'created_at': {"$gte":"Fri Dec 07 09:02:00 +0000 2018","$lte":"Fri Dec 07 10:02:00 +0000 2018"}}).count()
e[1,4]=db_twitter.Twitter1207_REMOVENOISE.find({'created_at': {"$gte":"Fri Dec 07 12:00:00 +0000 2018","$lte":"Fri Dec 07 13:00:00 +0000 2018"}}).count()
e[2,4]=db_twitter.Twitter1207_REMOVENOISE.find({'created_at': {"$gte":"Fri Dec 07 15:05:00 +0000 2018","$lte":"Fri Dec 07 16:05:00 +0000 2018"}}).count()
e[3,4]=db_twitter.Twitter1207_REMOVENOISE.find({'created_at': {"$gte":"Fri Dec 07 18:00:00 +0000 2018","$lte":"Fri Dec 07 19:00:00 +0000 2018"}}).count()
e[4,4]=db_twitter.Twitter1207_REMOVENOISE.find({'created_at': {"$gte":"Fri Dec 07 21:00:00 +0000 2018","$lte":"Fri Dec 07 22:00:00 +0000 2018"}}).count()
e[3,4]=e[3,4]*4
e[0,5]=db_twitter.Twitter1208_REMOVENOISE.find({'created_at': {"$gte":"Sat Dec 08 09:00:00 +0000 2018","$lte":"Sat Dec 08 10:00:00 +0000 2018"}}).count()
e[1,5]=db_twitter.Twitter1208_REMOVENOISE.find({'created_at': {"$gte":"Sat Dec 08 12:12:00 +0000 2018","$lte":"Sat Dec 08 13:12:00 +0000 2018"}}).count()
e[2,5]=db_twitter.Twitter1208_REMOVENOISE.find({'created_at': {"$gte":"Sat Dec 08 15:02:00 +0000 2018","$lte":"Sat Dec 08 16:02:00 +0000 2018"}}).count()
e[3,5]=db_twitter.Twitter1208_REMOVENOISE.find({'created_at': {"$gte":"Sat Dec 08 18:14:00 +0000 2018","$lte":"Sat Dec 08 19:14:00 +0000 2018"}}).count()
e[4,5]=db_twitter.Twitter1208_REMOVENOISE.find({'created_at': {"$gte":"Sat Dec 08 21:00:00 +0000 2018","$lte":"Sat Dec 08 22:00:00 +0000 2018"}}).count()
e[0,6]=db_twitter.Twitter1209_REMOVENOISE.find({'created_at': {"$gte":"Sun Dec 09 09:07:00 +0000 2018","$lte":"Sun Dec 09 10:07:00 +0000 2018"}}).count()
e[1,6]=db_twitter.Twitter1209_REMOVENOISE.find({'created_at': {"$gte":"Sun Dec 09 12:00:00 +0000 2018","$lte":"Sun Dec 09 13:00:00 +0000 2018"}}).count()
e[2,6]=db_twitter.Twitter1209_REMOVENOISE.find({'created_at': {"$gte":"Sun Dec 09 15:00:00 +0000 2018","$lte":"Sun Dec 09 16:00:00 +0000 2018"}}).count()
e[3,6]=db_twitter.Twitter1209_REMOVENOISE.find({'created_at': {"$gte":"Sun Dec 09 18:01:00 +0000 2018","$lte":"Sun Dec 09 19:01:00 +0000 2018"}}).count()
e[4,6]=db_twitter.Twitter1209_REMOVENOISE.find({'created_at': {"$gte":"Sun Dec 09 21:06:00 +0000 2018","$lte":"Sun Dec 09 22:06:00 +0000 2018"}}).count()
e
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# ...

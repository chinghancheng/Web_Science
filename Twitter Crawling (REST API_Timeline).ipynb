# %%
import oauth2 as oauth
import json
from scrapy import cmdline
import datetime
import time
import shutil
import os
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import pymongo
from pymongo import MongoClient,ASCENDING, DESCENDING
import pymongo,json
from pymongo import InsertOne, DeleteOne, ReplaceOne

# %%
ckey="UoHjDM87c0fFyNEVhBiwiKpxw"
csecret="Sw94LxDlQlsIHNBjODg81PFH5OXdFCQvFxDJ9p1NnPvdQlvQX4"
atoken="1044210663890063362-TgCKnfvdDnFCy9p3FmOISL3pj9K4pY"
asecret="bjH9LAiJrx8dd37ErkqeMUJirun8Zwk9aEYMtRL7lENo0"

# %%
import tweepy
import pandas as pd
import os
import numpy as np

#Twitter Access
auth = tweepy.OAuthHandler(ckey,csecret)
auth.set_access_token(atoken,asecret)
api = tweepy.API(auth,wait_on_rate_limit = True)

# %%
client = pymongo.MongoClient(host='localhost', port=27017)

# %%
db_twitter=client.TwitterTP
collection_twitter = db_twitter.Twitter_Timeline
print(collection_twitter)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'TwitterTP'), 'Twitter_Timeline')

# %%
all_data=[]
def RESTtimeline(name):
    
timeline = tweepy.Cursor(api.user_timeline,screen_name =name, count = 200, lang="en",include_rts = False).items(1000)
tweepy.Cursor(api.search, q=words,lang="en",count=100,until='').items(1000)
    
    for item in timeline:  
        all_data=item._json
        try:
            result=collection_twitter.insert_one(all_data)
            print(result)
        except ProgrammingError as err:
            print(err)
            return True

# %%
db_twitter=client.TwitterTP
collection_twitter = db_twitter.Twitter_Timeline_BBC
print(collection_twitter)
l=['BBCNews','BBCWorld','BBCBreaking','BBCSport','BBCScotlandNews','BBCScotland','BBCNewsbeat','BBCWalesNews','WalesPolitics'
   'BBCSportScot','BBCRadioScot','BBCtheSocial','BBCPolitics','BBCBusiness','BBCWorldBiz','bbchealth','bbcweather',
   'bbcworldservice','BBCNewsnight',]
for i in l:
    RESTtimeline(i)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'TwitterTP'), 'Twitter_Timeline_BBC')
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-6-26006342b024> in <module>()
#       6    'bbcworldservice','BBCNewsnight',]
#       7 for i in l:
# ----> 8     RESTtimeline(i)
#
# <ipython-input-5-8a561d547686> in RESTtimeline(name)
#       5     #search = tweepy.Cursor(api.search, q=[words],lang="en",count=100,until='2018-11-12').items(5000)
#       6     timeline = tweepy.Cursor(api.user_timeline,screen_name =name, count = 200, lang="en",include_rts = False).items(1000)
# ----> 7     for item in timeline:
#       8         all_data=item._json
#       9         try:
#
# ~\Anaconda3\lib\site-packages\tweepy-3.6.0-py3.7.egg\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ...

# %%
db_twitter=client.TwitterTP
collection_twitter = db_twitter.Twitter_Timeline_Herald
print(collection_twitter)
l=['heraldscotland','TheHerald_Sun','CatholicHerald','EverettHerald','calgaryherald','HeraldHeadlines','newcastleherald']
for i in l:
    RESTtimeline(i)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'TwitterTP'), 'Twitter_Timeline_Herald')
# ...
# ...
# ...

# %%
db_twitter=client.TwitterTP
collection_twitter = db_twitter.Twitter_Timeline_Scotsman
print(collection_twitter)
l=['TheScotsman','ScotsmanSport', 'Scot_Heritage', 'Scots_Future' ,'WeKnowScotland','visionscotmag','Scotsman_Prop',
  'scotsmanshowbiz','ScotsmanDebate','scotsman_arts','scot_business']
for i in l:
    RESTtimeline(i)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'TwitterTP'), 'Twitter_Timeline_Scotsman')
# ...
# ...
# ...
